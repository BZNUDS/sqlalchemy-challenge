# %%
import matplotlib
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
# create engine to hawaii.sqlite (BZ had to add Resources/)
engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# %%
# reflect an existing database into a new model
# Declare a Base using `automap_base()`
Base = automap_base()

# reflect the tables
# Use the Base class to reflect the database tables
Base.prepare(engine, reflect=True)

# %%
# View all of the classes that automap found
# Print all of the classes mapped to the Base
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
# Assign the dow class to a variable called `Dow`
Measurement = Base.classes.measurement
Station = Base.classes.station
print(f'Measurement: {Measurement}')
print(f'Station: {Station}')
# Out:
# Measurement: <class 'sqlalchemy.ext.automap.measurement'>
# Station: <class 'sqlalchemy.ext.automap.station'>

# %%
# Create our session (link) from Python to the DB
# Create a session
session = Session(engine)

# %%
# Display the row's columns and data in dictionary format
# Use the session to query Measurement table and display the row's columns and data in dictionary format
M=Measurement
Measurement_row = session.query(M).first()
print(f'Measurement_row.__dict__: {Measurement_row.__dict__}')

for row in session.query(M.date, M.tobs, M.id, M.station, M.prcp).limit(10).all():
    print(row)
    
S=Station
Station_row = session.query(S).first()
print(f'Station_row.__dict__: {Station_row.__dict__}')

for row in session.query(S.id, S.longitude, S.latitude, S.station, S.name, S.elevation).limit(3).all():
    print(row)
# Out:
# Measurement_row.__dict__: {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000025DA2E06D00>, 'date': '2010-01-01', 'tobs': 65.0, 'id': 1, 'station': 'USC00519397', 'prcp': 0.08}
# ('2010-01-01', 65.0, 1, 'USC00519397', 0.08)
# ('2010-01-02', 63.0, 2, 'USC00519397', 0.0)
# ('2010-01-03', 74.0, 3, 'USC00519397', 0.0)
# ('2010-01-04', 76.0, 4, 'USC00519397', 0.0)
# ('2010-01-06', 73.0, 5, 'USC00519397', None)
# ('2010-01-07', 70.0, 6, 'USC00519397', 0.06)
# ('2010-01-08', 64.0, 7, 'USC00519397', 0.0)
# ('2010-01-09', 68.0, 8, 'USC00519397', 0.0)
# ('2010-01-10', 73.0, 9, 'USC00519397', 0.0)
# ('2010-01-11', 64.0, 10, 'USC00519397', 0.01)
# Station_row.__dict__: {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000025DA6FFC100>, 'id': 1, 'longitude': -157.8168, 'latitude': 21.2716, 'station': 'USC00519397', 'name': 'WAIKIKI 717.2, HI US', 'elevation': 3.0}
# (1, -157.8168, 21.2716, 'USC00519397', 'WAIKIKI 717.2, HI US', 3.0)
# (2, -157.8015, 21.4234, 'USC00513117', 'KANEOHE 838.1, HI US', 14.6)
# (3, -157.8374, 21.5213, 'USC00514830', 'KUALOA RANCH HEADQUARTERS 886.9, HI US', 7.0)

# %%
# Display the row's columns and data in dictionary format
# Use the session to query Measurement table and display the row's columns and data in dictionary format
# Measurement_row = session.query(Measurement)
# for row in session.query(Measurement).all():
#     # print(row)
#     print(f'Measurement_row.__dict__: {Measurement_row.__dict__}')
    
# Display the row's columns and data in dictionary format
first_row = session.query(Measurement).first()
first_row.__dict__
print(f'first_row.__dict__: {first_row.__dict__}')

Measurement_row = session.query(Measurement).all()
for row in session.query(Measurement_row).limit(15).all():
    # print(row)
    print(f'Measurement_row.__dict__: {Measurement_row.__dict__}')

# print()
# print()

# Use the session to query Station table and display the row's columns and data in dictionary format
# Station_row = session.query(Station)
# for row in session.query(Station).all():
#     # print(row)
#     print(f'Station_row.__dict__: {Station_row.__dict__}')
# Out:
# first_row.__dict__: {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000025DA2E06D00>, 'date': '2010-01-01', 'tobs': 65.0, 'id': 1, 'station': 'USC00519397', 'prcp': 0.08}
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# C:\Users\BZNORT~1\AppData\Local\Temp/ipykernel_29808/3510205942.py in <module>
#      12
#      13 Measurement_row = session.query(Measurement).all()
# ---> 14 for row in session.query(Measurement_row).limit(15).all():
#      15     # print(row)
#      16     print(f'Measurement_row.__dict__: {Measurement_row.__dict__}')
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\session.py in query(self, *entities, **kwargs)
#    2104         """
#    2105
# -> 2106         return self._query_cls(entities, self, **kwargs)
#    2107
#    2108     def _identity_lookup(
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\query.py in __init__(self, entities, session)
#     178
#     179         self.session = session
# --> 180         self._set_entities(entities)
#     181
#     182     def _set_propagate_attrs(self, values):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\query.py in _set_entities(self, entities)
#     185
#     186     def _set_entities(self, entities):
# --> 187         self._raw_columns = [
#     188             coercions.expect(
#     189                 roles.ColumnsClauseRole,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\query.py in <listcomp>(.0)
#     186     def _set_entities(self, entities):
#     187         self._raw_columns = [
# --> 188             coercions.expect(
#     189                 roles.ColumnsClauseRole,
#     190                 ent,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\sql\coercions.py in expect(role, element, apply_propagate_attrs, argname, post_inspect, **kw)
#     185
#     186                 if resolved is None:
# --> 187                     resolved = impl._literal_coercion(
#     188                         element, argname=argname, **kw
#     189                     )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\sql\coercions.py in _literal_coercion(self, element, argname, **kw)
#     399             return elements.ColumnClause(str(element), is_literal=True)
#     400
# --> 401         self._raise_for_expected(element, argname)
#     402
#     403
#
# ~\anaconda3\lib\site-packages\sqlalchemy\sql\coercions.py in _raise_for_expected(self, element, argname, resolved, **kw)
#     435             advice = code = None
#     436
# --> 437         return super(_SelectIsNotFrom, self)._raise_for_expected(
#     438             element,
#     439             argname=argname,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\sql\coercions.py in _raise_for_expected(self, element, argname, resolved, advice, code, err)
#     281             msg += " " + advice
#     282
# --> 283         util.raise_(exc.ArgumentError(msg, code=code), replace_context=err)
#     284
#     285
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ArgumentError: Column expression or FROM clause expected, got [<sqlalchemy.ext.automap.measurement object at 0x0000025DA2F6D280>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA451C2E0>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA451CC10>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA451C790>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA451CD00>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA451C340>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA451C490>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA451C310>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA451C0A0>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA451C940>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA451C580>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA451C6A0>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA451CF10>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA451CAC0>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA33871C0>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA451C550>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA451C8B0>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA451C400>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA451C820>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA451C880>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA451C7C0>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA451C520>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA451CBB0>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA451C610>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA451CB80>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA451C040>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA451C3A0>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA451CDF0>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA451CAF0>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA451C460>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA451C160>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA451C1F0>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA451C3D0>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA451CA30>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA56EEF40>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA56EEC70>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA56EED90>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA56EE040>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA56EE0D0>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA56EE100>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA56EE130>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA56EE1F0>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA56EE220>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA56EE250>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA56EE310>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA56EE340>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA56EE370>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA56EE430>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA56EE460>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA56EE490>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA56EE550>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA56EE580>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA56EE5B0>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA56EE670>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA56EE6A0>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA56EE6D0>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA56EE790>, <sqlalchemy.ext.automap.measurement object at 0x0000025DA56EE7C0>, <sqlalchemy.ext.automap.measurement object at 0x000 ...

# %% [markdown]
# # Exploratory Precipitation Analysis

# %%
# Find the most recent date in the data set.

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results. 
# Starting from the most recent data point in the database. 

# Calculate the date one year from the last date in data set.


# Perform a query to retrieve the data and precipitation scores


# Save the query results as a Pandas DataFrame and set the index to the date column


# Sort the dataframe by date


# Use Pandas Plotting with Matplotlib to plot the data

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data

# %% [markdown]
# # Exploratory Station Analysis

# %%
# Design a query to calculate the total number stations in the dataset

# %%
# Design a query to find the most active stations (i.e. what stations have the most rows?)
# List the stations and the counts in descending order.

# %%
# Using the most active station id from the previous query, calculate the lowest, highest, and average temperature.

# %%
# Using the most active station id
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram

# %% [markdown]
# # Close session

# %%
# Close Session
session.close()
